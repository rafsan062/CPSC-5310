# %% [markdown]
# # TW1
#
# ## Pandas Series and DataFrame
#
# - Practice Pandas Series and DataFrame with examples.

# %% [markdown]
# ## Name: Rizvan Ahmed Rafsan

# %% [markdown]
# ## Part 0
#
# Practice Pandas Series and DataFrame with the given examples.

# %%
import pandas as pd

# %%
alist = ['Mouse', 'Giraffe', 'Tiger', 'Dog', 'Hippopotamus', 'Moose', 'Bear']
animals = pd.Series(alist)
animals
# Out:
# 0           Mouse
# 1         Giraffe
# 2           Tiger
# 3             Dog
# 4    Hippopotamus
# 5           Moose
# 6            Bear
# dtype: object

# %%
animals[2]
# Out:
# 'Tiger'

# %%
animals.iloc[2]
# Out:
# 'Tiger'

# %%
animals.loc[2]
# Out:
# 'Tiger'

# %%
s1 = pd.Series(alist, index=[0, 1, 2, 3, 4, 5, 6])
s1.iloc[2]
# Out:
# 'Tiger'

# %%
s1.loc[2]
# Out:
# 'Tiger'

# %%
s2 = pd.Series(alist, index=['a', 'b', 'c', 'd', 'e', 'f', 'g'])
s2
# Out:
# a           Mouse
# b         Giraffe
# c           Tiger
# d             Dog
# e    Hippopotamus
# f           Moose
# g            Bear
# dtype: object

# %%
s2['c']
# Out:
# 'Tiger'

# %%
s2.iloc[2]
# Out:
# 'Tiger'

# %%
names = ['Chris', 'Kevin', 'Bob', 'Vinod', 'Daniel', 'Fil', 'Stephanie']
owners = pd.Series(names)
owners
# Out:
# 0        Chris
# 1        Kevin
# 2          Bob
# 3        Vinod
# 4       Daniel
# 5          Fil
# 6    Stephanie
# dtype: object

# %%
frame = {'animals': animals, 'owners': owners}

df = pd.DataFrame(frame)

df
# Out:
#         animals     owners
# 0         Mouse      Chris
# 1       Giraffe      Kevin
# 2         Tiger        Bob
# 3           Dog      Vinod
# 4  Hippopotamus     Daniel
# 5         Moose        Fil
# 6          Bear  Stephanie

# %%
df.columns
# Out:
# Index(['animals', 'owners'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
type(df['animals'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0]
# Out:
# animals    Mouse
# owners     Chris
# Name: 0, dtype: object

# %%
df.loc[0][1]
# Out:
# /var/folders/x2/3118c13j6_114k46f2zqb35c0000gp/T/ipykernel_9692/395987507.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][1]
# 'Chris'

# %%
df.owners
# Out:
# 0        Chris
# 1        Kevin
# 2          Bob
# 3        Vinod
# 4       Daniel
# 5          Fil
# 6    Stephanie
# Name: owners, dtype: object

# %%
df['owners']
# Out:
# 0        Chris
# 1        Kevin
# 2          Bob
# 3        Vinod
# 4       Daniel
# 5          Fil
# 6    Stephanie
# Name: owners, dtype: object

# %%
# copy an existing DataFrame to create a new dataFrame
copy_df = df.copy()
copy_df
# Out:
#         animals     owners
# 0         Mouse      Chris
# 1       Giraffe      Kevin
# 2         Tiger        Bob
# 3           Dog      Vinod
# 4  Hippopotamus     Daniel
# 5         Moose        Fil
# 6          Bear  Stephanie

# %%
# drop columns

df2 = df.drop(['owners'], axis = 1)

df2
# Out:
#         animals
# 0         Mouse
# 1       Giraffe
# 2         Tiger
# 3           Dog
# 4  Hippopotamus
# 5         Moose
# 6          Bear

# %%
# drop columns

df3 = df.drop(columns = ['owners'])

df3
# Out:
#         animals
# 0         Mouse
# 1       Giraffe
# 2         Tiger
# 3           Dog
# 4  Hippopotamus
# 5         Moose
# 6          Bear

# %%
# drop rows

df4 = df.drop([0,1])
df4
# Out:
#         animals     owners
# 2         Tiger        Bob
# 3           Dog      Vinod
# 4  Hippopotamus     Daniel
# 5         Moose        Fil
# 6          Bear  Stephanie

# %%
midx = pd.MultiIndex(levels=[['lama', 'cow', 'falcon'],
                             ['speed', 'weight']],
                     codes=[[0, 0, 1, 1, 2, 2],
                            [0, 1, 0, 1, 0, 1]])

midx
# Out:
# MultiIndex([(  'lama',  'speed'),
#             (  'lama', 'weight'),
#             (   'cow',  'speed'),
#             (   'cow', 'weight'),
#             ('falcon',  'speed'),
#             ('falcon', 'weight')],
#            )

# %%
df = pd.DataFrame(index=midx, columns=['big', 'small'],
                   data=[[45, 30], [200, 100], [30, 20], [250, 150], [320, 250],[1, 0.8]])

df
# Out:
#                big  small
# lama   speed    45   30.0
#        weight  200  100.0
# cow    speed    30   20.0
#        weight  250  150.0
# falcon speed   320  250.0
#        weight    1    0.8

# %%
df.drop(index='cow', columns='small')
# Out:
#                big
# lama   speed    45
#        weight  200
# falcon speed   320
#        weight    1

# %%
df.drop(index='weight', level=1)
# Out:
#               big  small
# lama   speed   45   30.0
# cow    speed   30   20.0
# falcon speed  320  250.0

# %% [markdown]
# ## Part 1 Task 1
#
# Given the data below, implement each tasks.
#
# <img src="img/df.png" style="height:200px">
#
# (1) Create a DataFrame.
#
# (2) Access the first row data and print it.
#
# (3) Access the first column data (indexed by 'dept') and print it.
#
# (4) Create a new DataFrame by dropping the 2nd column data (indexed by 'floor') from the current DataFrame.

# %% [markdown]
# ### 1. Create a DataFrame.

# %%
# Create a DataFrame using lists and Series
dept_list = ['CS', 'Bio', 'Chem', 'Phy', 'Eng']
floor_list = [5, 3, 3, 2, 4]

dept = pd.Series(dept_list)
floor = pd.Series(floor_list)

frame = {'dept': dept, 'floor': floor}
df = pd.DataFrame(frame)
df
# Out:
#    dept  floor
# 0    CS      5
# 1   Bio      3
# 2  Chem      3
# 3   Phy      2
# 4   Eng      4

# %% [markdown]
# ### 2. Access the first row data and print it.

# %%
print(df.iloc[0])
# Out:
# dept     CS
# floor     5
# Name: 0, dtype: object

# %% [markdown]
# ### 3. Access the first column data (indexed by 'dept') and print it.

# %%
print(df['dept'])
# Out:
# 0      CS
# 1     Bio
# 2    Chem
# 3     Phy
# 4     Eng
# Name: dept, dtype: object

# %% [markdown]
# ### 4. Create a new DataFrame by dropping the 2nd column data (indexed by 'floor') from the current DataFrame.

# %%
df_new = df.drop(columns=['floor'])
print(df_new)
# Out:
#    dept
# 0    CS
# 1   Bio
# 2  Chem
# 3   Phy
# 4   Eng

# %% [markdown]
# ## Part 1 Task 2
#
# Practice with a data file.
#
# (1) Choose one data file from the data folder in the given TW1 folder.
#
# (2) Read the data into a DataFrame.
#
# (3) Access the rows and columns.
#
# (4) Drop some columns.

# %% [markdown]
# ### 1. Choose one data file from the data folder in the given TW1 folder.

# %% [markdown]
# #### Data file chosen: asthma.csv

# %% [markdown]
# ### 2. Read the data into a DataFrame.

# %%
df = pd.read_csv('./data/asthma.csv')
df.head()
# Out:
#        ID     Date  Temp_Mean  Humi_Mean  PM25_Mean_R     CO2_Mean  \
# 0  SB-011  11/1/17  23.477778  50.243056    47.041667   904.877778
# 1  SB-011  11/2/17  23.401875  55.382639    40.629236   998.941667
# 2  SB-011  11/3/17  23.446111  53.793056    43.817847   996.820833
# 3  SB-011  11/4/17  23.305417  49.570139    54.553681  1230.109722
# 4  SB-011  11/5/17  22.997708  46.295139    41.140208  1297.323611
#
#    PEFR_Morning  PEFR_After  PEFR_Max    Birth  Age  Gender       BMI  Income  \
# 0           280         300       300  3/23/53   66       1  21.34867       5
# 1           270         300       300  3/23/53   66       1  21.34867       5
# 2           280         310       310  3/23/53   66       1  21.34867       5
# 3           280         310       310  3/23/53   66       1  21.34867       5
# 4           280         310       310  3/23/53   66       1  21.34867       5
#
#    Road_Distance  Cooking  Height
# 0              2        3   151.5
# 1              2        3   151.5
# 2              2        3   151.5
# 3              2        3   151.5
# 4              2        3   151.5

# %% [markdown]
# ### 3. Access the rows and columns.

# %%
# Accessing first and second rows
df.iloc[0:2]
# Out:
#        ID     Date  Temp_Mean  Humi_Mean  PM25_Mean_R    CO2_Mean  \
# 0  SB-011  11/1/17  23.477778  50.243056    47.041667  904.877778
# 1  SB-011  11/2/17  23.401875  55.382639    40.629236  998.941667
#
#    PEFR_Morning  PEFR_After  PEFR_Max    Birth  Age  Gender       BMI  Income  \
# 0           280         300       300  3/23/53   66       1  21.34867       5
# 1           270         300       300  3/23/53   66       1  21.34867       5
#
#    Road_Distance  Cooking  Height
# 0              2        3   151.5
# 1              2        3   151.5

# %%
# Accessing CO2_Mean column
df['CO2_Mean']
# Out:
# 0       904.877778
# 1       998.941667
# 2       996.820833
# 3      1230.109722
# 4      1297.323611
#           ...
# 175    1199.881250
# 176    1320.761806
# 177    1162.570833
# 178    1147.852778
# 179    1339.854167
# Name: CO2_Mean, Length: 180, dtype: float64

# %% [markdown]
# ### 4. Drop some columns.

# %%
# Dropping PEFR_Morning and	PEFR_After columns
df_new = df.drop(columns=['PEFR_Morning', 'PEFR_After'])
df_new.head()
# Out:
#        ID     Date  Temp_Mean  Humi_Mean  PM25_Mean_R     CO2_Mean  PEFR_Max  \
# 0  SB-011  11/1/17  23.477778  50.243056    47.041667   904.877778       300
# 1  SB-011  11/2/17  23.401875  55.382639    40.629236   998.941667       300
# 2  SB-011  11/3/17  23.446111  53.793056    43.817847   996.820833       310
# 3  SB-011  11/4/17  23.305417  49.570139    54.553681  1230.109722       310
# 4  SB-011  11/5/17  22.997708  46.295139    41.140208  1297.323611       310
#
#      Birth  Age  Gender       BMI  Income  Road_Distance  Cooking  Height
# 0  3/23/53   66       1  21.34867       5              2        3   151.5
# 1  3/23/53   66       1  21.34867       5              2        3   151.5
# 2  3/23/53   66       1  21.34867       5              2        3   151.5
# 3  3/23/53   66       1  21.34867       5              2        3   151.5
# 4  3/23/53   66       1  21.34867       5              2        3   151.5
